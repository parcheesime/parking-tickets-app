# %% [markdown]
# ### Merge Parking Ticket Data
#
# Function to merge Los Angeles Parking Ticket data, without duplicates.
#
# [Parking Tickets API](https://dev.socrata.com/foundry/data.lacity.org/4f5p-udkv)
#
# [Paging through Data](https://dev.socrata.com/docs/paging)

# %%
import requests
import json
from config import get_api_token
import pandas as pd

# %%
# token, adjust tickets limits

app_token = get_api_token()
print(app_token)
base_url = 'https://data.lacity.org/resource/4f5p-udkv.json'

# get headers
headers = {
    'Accept': 'application/json',  
    'X-App-Token': app_token  
}
    
# Define the schema with default values
schema = {
    'agency': None,
    'agency_desc': None,
    'body_style': None,
    'body_style_desc': None,
    'color': None,
    'color_desc': None,
    'fine_amount': None,
    'issue_date': None,
    'issue_time': None,
    'loc_lat': None,
    'loc_long': None,
    'location': None,
    'make': None,
    'marked_time': None,
    'meter_id': None,
    'plate_expiry_date': None,
    'rp_state_plate': None,
    'ticket_number': None,
    'violation_code': None,
    'violation_description': None
}

# schema for data
def apply_schema(data, schema):
    """Apply the schema to individual data entries."""
    return {key: data.get(key, schema[key]) for key in schema}

# function to get initial data
def fetch_pages(base_url, limit, pages, schema, headers):
    all_data = []
    order = "issue_date ASC, issue_time ASC, ticket_number ASC"  # Ordering by date, time, then ticket number
    for page in range(pages):
        offset = limit * page
        url = f"{base_url}?$limit={limit}&$offset={offset}&$order={order}"
        response = requests.get(url, headers=headers)
        
        if response.status_code == 200:
            raw_data = response.json()
            # Apply the schema to each item in the data
            normalized_data = [apply_schema(item, schema) for item in raw_data]
            all_data.extend(normalized_data)
            print(f"Fetched page {page + 1} with {len(normalized_data)} records.")
        else:
            print(f"Failed to fetch data on page {page + 1}: {response.status_code}")
            break
    
    return all_data

def fetch_and_count_records(base_url, limit, page_count):
    all_data = []
    for page in range(page_count):
        offset = limit * page
        url = f"{base_url}?$limit={limit}&$offset={offset}"
        response = requests.get(url)

        if response.status_code == 200:
            data = response.json()
            all_data.extend(data) 
            print(f"Page {page + 1}: Fetched {len(data)} records.")
        else:
            print(f"Error fetching page {page + 1}: HTTP {response.status_code}")
            break  # exit the loop on error
    return all_data
# Out:
# ZzVI2vN6lETzguOojTmivo03L

# %%
# adding ticket data to existing data

def fetch_additional_records(base_url, limit, existing_data, schema, headers):
    if not existing_data:
        print("No existing data to determine the latest record.")
        return

    # Sort existing data by issue_date and ticket_number to find the latest one
    existing_data_sorted = sorted(existing_data, key=lambda x: (x['issue_date'], int(x['ticket_number'])))
    latest_record = existing_data_sorted[-1]
    
    # Build a condition to fetch records after the latest one
    where_condition = f"issue_date>'{latest_record['issue_date']}' OR (issue_date='{latest_record['issue_date']}' AND ticket_number>'{latest_record['ticket_number']}')"

    # Prepare the URL with the where condition
    url = f"{base_url}?$limit={limit}&$where={where_condition}&$order=issue_date ASC, ticket_number ASC"
    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        new_data = response.json()
        if not new_data:
            print("No new data found.")
            return

        # Apply the schema to each incoming record
        normalized_new_data = [apply_schema(record, schema) for record in new_data]
        
        # Merge new records
        existing_data.extend(normalized_new_data)
        print(f"Added {len(normalized_new_data)} new records to the existing data.")
    else:
        print(f"Failed to fetch data: {response.status_code}")

# %%
import pprint
limit = 1050  # records per page
pages = 1  # pages to fetch
order =  "ticket_number"
data = fetch_pages(base_url, limit, pages, schema, headers)

print(f"Total records fetched: {len(data)}")


existing = (data[:100])  # test set of records
# Out:
# Fetched page 1 with 1050 records.
# Total records fetched: 1050

# %%
existing
# Out:
# [{'agency': '2',
#   'agency_desc': 'LAX CURRENT',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'WH',
#   'color_desc': None,
#   'fine_amount': None,
#   'issue_date': '1950-07-15T00:00:00.000',
#   'issue_time': '1550',
#   'loc_lat': '33.9430863',
#   'loc_long': '-118.3995274',
#   'location': '701 WORLD WAY',
#   'make': 'LAND',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': '201910',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1127488375',
#   'violation_code': None,
#   'violation_description': None},
#  {'agency': '1',
#   'agency_desc': 'WESTERN',
#   'body_style': 'SU',
#   'body_style_desc': None,
#   'color': 'BK',
#   'color_desc': 'BLACK',
#   'fine_amount': None,
#   'issue_date': '1962-01-30T00:00:00.000',
#   'issue_time': '1650',
#   'loc_lat': '34.0337275',
#   'loc_long': '-118.2653638',
#   'location': '8TH ST W/O HILL ST',
#   'make': 'JEEP',
#   'marked_time': None,
#   'meter_id': 'CB3235',
#   'plate_expiry_date': '202005',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1121858091',
#   'violation_code': None,
#   'violation_description': None},
#  {'agency': '1',
#   'agency_desc': 'WESTERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'BK',
#   'color_desc': 'BLACK',
#   'fine_amount': None,
#   'issue_date': '1970-01-31T00:00:00.000',
#   'issue_time': '1840',
#   'loc_lat': '34.0367254',
#   'loc_long': '-118.2682253',
#   'location': 'VENICE-PEMBROKE',
#   'make': 'HOND',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': '202003',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1121875510',
#   'violation_code': None,
#   'violation_description': None},
#  {'agency': '1',
#   'agency_desc': 'WESTERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'GY',
#   'color_desc': 'GREY',
#   'fine_amount': None,
#   'issue_date': '1972-01-22T00:00:00.000',
#   'issue_time': '1555',
#   'loc_lat': '34.1564506',
#   'loc_long': '-118.4391616',
#   'location': '14000 RIVERSIDE DR',
#   'make': 'TOYO',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': '202009',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1121270581',
#   'violation_code': None,
#   'violation_description': None},
#  {'agency': '1',
#   'agency_desc': 'WESTERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'TA',
#   'color_desc': None,
#   'fine_amount': None,
#   'issue_date': '1972-01-30T00:00:00.000',
#   'issue_time': '1805',
#   'loc_lat': '34.0451361',
#   'loc_long': '-118.256675',
#   'location': '8TH ST W/O OLIVE',
#   'make': 'TOYO',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': '202004',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1121858124',
#   'violation_code': None,
#   'violation_description': None},
#  {'agency': '2',
#   'agency_desc': 'LAX CURRENT',
#   'body_style': 'TR',
#   'body_style_desc': 'TRAILER',
#   'color': 'GY',
#   'color_desc': 'GREY',
#   'fine_amount': '0',
#   'issue_date': '2000-01-06T00:00:00.000',
#   'issue_time': '642',
#   'loc_lat': '33.9430863',
#   'loc_long': '-118.3995274',
#   'location': '700 WORLD WAY U/L',
#   'make': 'FORD',
#   'marked_time': '0000',
#   'meter_id': None,
#   'plate_expiry_date': '202209',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1128903263',
#   'violation_code': '8939',
#   'violation_description': None},
#  {'agency': '54',
#   'agency_desc': '54 - DOT - HOLLYWOOD',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'BK',
#   'color_desc': 'BLACK',
#   'fine_amount': '0',
#   'issue_date': '2000-01-25T00:00:00.000',
#   'issue_time': '932',
#   'loc_lat': '34.079314',
#   'loc_long': '-118.313661',
#   'location': '5042 ROSEWOOD AV',
#   'make': 'SUBA',
#   'marked_time': '0000',
#   'meter_id': None,
#   'plate_expiry_date': '202110',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1126402771',
#   'violation_code': '8069BS',
#   'violation_description': None},
#  {'agency': '1',
#   'agency_desc': 'WESTERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'SI',
#   'color_desc': None,
#   'fine_amount': '0',
#   'issue_date': '2000-01-28T00:00:00.000',
#   'issue_time': '1125',
#   'loc_lat': '34.1854392',
#   'loc_long': '-118.6105479',
#   'location': '22216 VICTORY BL',
#   'make': 'HOND',
#   'marked_time': '0000',
#   'meter_id': None,
#   'plate_expiry_date': '201905',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1125067753',
#   'violation_code': '4000A1',
#   'violation_description': None},
#  {'agency': '1',
#   'agency_desc': 'WESTERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'GO',
#   'color_desc': 'GOLD',
#   'fine_amount': '0',
#   'issue_date': '2000-01-28T00:00:00.000',
#   'issue_time': '1700',
#   'loc_lat': '34.1886520',
#   'loc_long': '-118.5884555',
#   'location': 'KITTRIDGE W/O DE SOT',
#   'make': 'ACUR',
#   'marked_time': '0000',
#   'meter_id': None,
#   'plate_expiry_date': '202103',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1125033442',
#   'violation_code': '4000A1',
#   'violation_description': None},
#  {'agency': '1',
#   'agency_desc': 'WESTERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'BK',
#   'color_desc': 'BLACK',
#   'fine_amount': '0',
#   'issue_date': '2000-02-05T00:00:00.000',
#   'issue_time': '1130',
#   'loc_lat': '34.0536473',
#   'loc_long': '-118.2455167',
#   'location': '32/BROADWAY',
#   'make': 'HOND',
#   'marked_time': '0000',
#   'meter_id': None,
#   'plate_expiry_date': '202011',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1121626240',
#   'violation_code': '4000A1',
#   'violation_description': None},
#  {'agency': '1',
#   'agency_desc': 'WESTERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'WH',
#   'color_desc': None,
#   'fine_amount': '0',
#   'issue_date': '2000-02-16T00:00:00.000',
#   'issue_time': '1440',
#   'loc_lat': '34.1015455',
#   'loc_long': '-118.3402566',
#   'location': 'HOLLYWOOD/IVAR',
#   'make': 'BMW',
#   'marked_time': '0000',
#   'meter_id': None,
#   'plate_expiry_date': '202205',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1125070601',
#   'violation_code': '8056E4',
#   'violation_description': None},
#  {'agency': '55',
#   'agency_desc': '55 - DOT - SOUTHERN',
#   'body_style': 'TL',
#   'body_style_desc': None,
#   'color': 'OR',
#   'color_desc': 'ORANGE',
#   'fine_amount': '0',
#   'issue_date': '2000-04-15T00:00:00.000',
#   'issue_time': '742',
#   'loc_lat': '33.7743384',
#   'loc_long': '-118.2629927',
#   'location': '400 N MARINE AV',
#   'make': 'UNK',
#   'marked_time': '0000',
#   'meter_id': None,
#   'plate_expiry_date': '0',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1126863172',
#   'violation_code': None,
#   'violation_description': None},
#  {'agency': '51',
#   'agency_desc': '51 - DOT - WESTERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'GY',
#   'color_desc': 'GREY',
#   'fine_amount': '0',
#   'issue_date': '2000-04-18T00:00:00.000',
#   'issue_time': '1237',
#   'loc_lat': '34.00352251',
#   'loc_long': '-118.43357788',
#   'location': '12326 VENICE BL',
#   'make': 'BMW',
#   'marked_time': '0000',
#   'meter_id': 'MV146',
#   'plate_expiry_date': '0',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1126961570',
#   'violation_code': '8813B',
#   'violation_description': None},
#  {'agency': '1',
#   'agency_desc': 'WESTERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'WH',
#   'color_desc': None,
#   'fine_amount': None,
#   'issue_date': '2000-05-14T00:00:00.000',
#   'issue_time': '5',
#   'loc_lat': '34.0169200',
#   'loc_long': '-118.2174570',
#   'location': '2900 E WASHINGTON BL',
#   'make': 'PONT',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': '202004',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1124673001',
#   'violation_code': None,
#   'violation_description': None},
#  {'agency': '1',
#   'agency_desc': 'WESTERN',
#   'body_style': 'RV',
#   'body_style_desc': None,
#   'color': 'WH',
#   'color_desc': None,
#   'fine_amount': None,
#   'issue_date': '2000-11-19T00:00:00.000',
#   'issue_time': '1214',
#   'loc_lat': '34.1858995',
#   'loc_long': '-118.4123454',
#   'location': '12813 FRIAR ST',
#   'make': 'TIOG',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': '201205',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1124727785',
#   'violation_code': None,
#   'violation_description': None},
#  {'agency': '51',
#   'agency_desc': '51 - DOT - WESTERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'BK',
#   'color_desc': 'BLACK',
#   'fine_amount': '25',
#   'issue_date': '2001-06-30T00:00:00.000',
#   'issue_time': '1247',
#   'loc_lat': '34.07373345',
#   'loc_long': '-118.50609121',
#   'location': '2100 QUEENSFERRY ROAD',
#   'make': 'MERZ',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': '202108',
#   'rp_state_plate': 'CA',
#   'ticket_number': '4525405010',
#   'violation_code': '5200',
#   'violation_description': 'DISPLAY OF PLATES'},
#  {'agency': '54',
#   'agency_desc': '54 - DOT - HOLLYWOOD',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'RD',
#   'color_desc': 'RED',
#   'fine_amount': '68',
#   'issue_date': '2001-07-25T00:00:00.000',
#   'issue_time': '1335',
#   'loc_lat': '34.0927209',
#   'loc_long': '-118.3855378',
#   'location': '1269 OZETA TER',
#   'make': 'LEXS',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': '202106',
#   'rp_state_plate': 'CA',
#   'ticket_number': '4526155922',
#   'violation_code': '22514',
#   'violation_description': 'FIRE HYDRANT'},
#  {'agency': '54',
#   'agency_desc': '54 - DOT - HOLLYWOOD',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'GY',
#   'color_desc': 'GREY',
#   'fine_amount': '68',
#   'issue_date': '2001-08-12T00:00:00.000',
#   'issue_time': '2125',
#   'loc_lat': '34.0935627',
#   'loc_long': '-118.3365151',
#   'location': '1210 CHEROKEE AV N',
#   'make': 'TOYT',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': '202106',
#   'rp_state_plate': 'CA',
#   'ticket_number': '4528306790',
#   'violation_code': '80.58L',
#   'violation_description': 'PREFERENTIAL PARKING'},
#  {'agency': '54',
#   'agency_desc': '54 - DOT - HOLLYWOOD',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'GY',
#   'color_desc': 'GREY',
#   'fine_amount': '68',
#   'issue_date': '2001-08-12T00:00:00.000',
#   'issue_time': '2126',
#   'loc_lat': '34.0935627',
#   'loc_long': '-118.3365151',
#   'location': '1210 CHEROKEE AV N',
#   'make': 'AUDI',
#   'marked_time': '0000',
#   'meter_id': None,
#   'plate_expiry_date': '201911',
#   'rp_state_plate': 'CA',
#   'ticket_number': '4528306801',
#   'violation_code': '80.58L',
#   'violation_description': 'PREFERENTIAL PARKING'},
#  {'agency': '54',
#   'agency_desc': '54 - DOT - HOLLYWOOD',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'GY',
#   'color_desc': 'GREY',
#   'fine_amount': '25',
#   'issue_date': '2001-08-12T00:00:00.000',
#   'issue_time': '2127',
#   'loc_lat': '34.0938367',
#   'loc_long': '-118.3379762',
#   'location': '1210 CHEROKEE AV N',
#   'make': 'AUDI',
#   'marked_time': '0000',
#   'meter_id': None,
#   'plate_expiry_date': '201911',
#   'rp_state_plate': 'CA',
#   'ticket_number': '4528306812',
#   'violation_code': '5200',
#   'violation_description': 'DISPLAY OF PLATES'},
#  {'agency': '54',
#   'agency_desc': '54 - DOT - HOLLYWOOD',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'GY',
#   'color_desc': 'GREY',
#   'fine_amount': '93',
#   'issue_date': '2001-08-12T00:00:00.000',
#   'issue_time': '2144',
#   'loc_lat': '34.1044841',
#   'loc_long': '-118.3018098',
#   'location': '1825 KINGSLEY DR N',
#   'make': 'MERZ',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': None,
#   'rp_state_plate': 'CA',
#   'ticket_number': '4528306823',
#   'violation_code': '80.56E4+',
#   'violation_description': 'RED ZONE'},
#  {'agency': '51',
#   'agency_desc': '51 - DOT - WESTERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'SL',
#   'color_desc': 'SILVER',
#   'fine_amount': '63',
#   'issue_date': '2001-12-16T00:00:00.000',
#   'issue_time': '1240',
#   'loc_lat': '34.06047081',
#   'loc_long': '-118.44229773',
#   'location': '1001 HILGARD AV',
#   'make': 'FORD',
#   'marked_time': '0000',
#   'meter_id': 'WV479',
#   'plate_expiry_date': '202112',
#   'rp_state_plate': 'CA',
#   'ticket_number': '4533651953',
#   'violation_code': '88.13B+',
#   'violation_description': 'METER EXP.'},
#  {'agency': '51',
#   'agency_desc': '51 - DOT - WESTERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'BK',
#   'color_desc': 'BLACK',
#   'fine_amount': '73',
#   'issue_date': '2002-02-21T00:00:00.000',
#   'issue_time': '1238',
#   'loc_lat': '34.0023154',
#   'loc_long': '-118.4592869',
#   'location': '1064 ELKGROVE AVE',
#   'make': 'CHEV',
#   'marked_time': '0000',
#   'meter_id': None,
#   'plate_expiry_date': '202112',
#   'rp_state_plate': 'CA',
#   'ticket_number': '4537262376',
#   'violation_code': '80.69BS',
#   'violation_description': 'NO PARK/STREET CLEAN'},
#  {'agency': '51',
#   'agency_desc': '51 - DOT - WESTERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'SL',
#   'color_desc': 'SILVER',
#   'fine_amount': '25',
#   'issue_date': '2002-04-18T00:00:00.000',
#   'issue_time': '1434',
#   'loc_lat': '34.0019331',
#   'loc_long': '-118.459141',
#   'location': '1046 ELKGROVE AVE',
#   'make': 'BMW',
#   'marked_time': '0000',
#   'meter_id': None,
#   'plate_expiry_date': '202106',
#   'rp_state_plate': 'CA',
#   'ticket_number': '4539788422',
#   'violation_code': '5204A-',
#   'violation_description': 'DISPLAY OF TABS'},
#  {'agency': '51',
#   'agency_desc': '51 - DOT - WESTERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'SL',
#   'color_desc': 'SILVER',
#   'fine_amount': '73',
#   'issue_date': '2002-04-18T00:00:00.000',
#   'issue_time': '1435',
#   'loc_lat': '34.0020121',
#   'loc_long': '-118.4591001',
#   'location': '1046 ELKGROVE AVE',
#   'make': 'BMW',
#   'marked_time': '0000',
#   'meter_id': None,
#   'plate_expiry_date': '202106',
#   'rp_state_plate': 'CA',
#   'ticket_number': '4539788433',
#   'violation_code': '80.69BS',
#   'violation_description': 'NO PARK/STREET CLEAN'},
#  {'agency': '51',
#   'agency_desc': '51 - DOT - WESTERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'BK',
#   'color_desc': 'BLACK',
#   'fine_amount': '73',
#   'issue_date': '2002-06-06T00:00:00.000',
#   'issue_time': '1433',
#   'loc_lat': '34.0022233',
#   'loc_long': '-118.4590563',
#   'location': '1062 ELKGROVE AVE',
#   'make': 'PORS',
#   'marked_time': '0000',
#   'meter_id': None,
#   'plate_expiry_date': '0',
#   'rp_state_plate': 'CO',
#   'ticket_number': '4541656873',
#   'violation_code': '80.69BS',
#   'violation_description': 'NO PARK/STREET CLEAN'},
#  {'agency': '51',
#   'agency_desc': '51 - DOT - WESTERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'BK',
#   'color_desc': 'BLACK',
#   'fine_amount': '73',
#   'issue_date': '2002-06-06T00:00:00.000',
#   'issue_time': '1434',
#   'loc_lat': '34.0021854',
#   'loc_long': '-118.4590565',
#   'location': '1046 ELKGROVE AVE',
#   'make': 'VOLK',
#   'marked_time': '0000',
#   'meter_id': None,
#   'plate_expiry_date': '202109',
#   'rp_state_plate': 'CA',
#   'ticket_number': '4541656884',
#   'violation_code': '80.69BS',
#   'violation_description': 'NO PARK/STREET CLEAN'},
#  {'agency': '51',
#   'agency_desc': '51 - DOT - WESTERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'BK',
#   'color_desc': 'BLACK',
#   'fine_amount': '25',
#   'issue_date': '2002-06-06T00:00:00.000',
#   'issue_time': '1435',
#   'loc_lat': '34.0019867',
#   'loc_long': '-118.4593299',
#   'location': '1046 ELKGROVE AVE',
#   'make': 'VOLK',
#   'marked_time': '0000',
#   'meter_id': None,
#   'plate_expiry_date': '202109',
#   'rp_state_plate': 'CA',
#   'ticket_number': '4541656895',
#   'violation_code': '5204A-',
#   'violation_description': 'DISPLAY OF TABS'},
#  {'agency': '51',
#   'agency_desc': '51 - DOT - WESTERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'WT',
#   'color_desc': 'WHITE',
#   'fine_amount': '73',
#   'issue_date': '2002-06-06T00:00:00.000',
#   'issue_time': '1436',
#   'loc_lat': '34.0019868',
#   'loc_long': '-118.4591897',
#   'location': '1046 ELKGROVE AVE',
#   'make': 'HOND',
#   'marked_time': '0000',
#   'meter_id': None,
#   'plate_expiry_date': '202203',
#   'rp_state_plate': 'MT',
#   'ticket_number': '4541656906',
#   'violation_code': '80.69BS',
#   'violation_description': 'NO PARK/STREET CLEAN'},
#  {'agency': '54',
#   'agency_desc': '54 - DOT - HOLLYWOOD',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'GY',
#   'color_desc': 'GREY',
#   'fine_amount': '63',
#   'issue_date': '2002-06-08T00:00:00.000',
#   'issue_time': '1121',
#   'loc_lat': '34.1009088',
#   'loc_long': '-118.3237874',
#   'location': '1400 SEWARD ST',
#   'make': 'MERZ',
#   'marked_time': '0000',
#   'meter_id': 'SV871',
#   'plate_expiry_date': '202211',
#   'rp_state_plate': 'CA',
#   'ticket_number': '4541791822',
#   'violation_code': '88.13B+',
#   'violation_description': 'METER EXP.'},
#  {'agency': '51',
#   'agency_desc': '51 - DOT - WESTERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'BK',
#   'color_desc': 'BLACK',
#   'fine_amount': '68',
#   'issue_date': '2002-06-29T00:00:00.000',
#   'issue_time': '1017',
#   'loc_lat': '34.0021066',
#   'loc_long': '-118.4592358',
#   'location': '1061 ELKGROVE AVE',
#   'make': 'HOND',
#   'marked_time': '0000',
#   'meter_id': None,
#   'plate_expiry_date': '202209',
#   'rp_state_plate': 'CA',
#   'ticket_number': '4543206883',
#   'violation_code': '22500H',
#   'violation_description': 'DOUBLE PARKING'},
#  {'agency': '54',
#   'agency_desc': '54 - DOT - HOLLYWOOD',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'BK',
#   'color_desc': 'BLACK',
#   'fine_amount': '68',
#   'issue_date': '2002-07-06T00:00:00.000',
#   'issue_time': '1407',
#   'loc_lat': '34.1051385',
#   'loc_long': '-118.346111',
#   'location': '1850 LA BREA AVE N',
#   'make': 'CHEV',
#   'marked_time': '0000',
#   'meter_id': None,
#   'plate_expiry_date': '1',
#   'rp_state_plate': 'CA',
#   'ticket_number': '4544071630',
#   'violation_code': '80.58L',
#   'violation_description': 'PREFERENTIAL PARKING'},
#  {'agency': '51',
#   'agency_desc': '51 - DOT - WESTERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'RD',
#   'color_desc': 'RED',
#   'fine_amount': '25',
#   'issue_date': '2002-07-08T00:00:00.000',
#   'issue_time': '1224',
#   'loc_lat': '34.07532024',
#   'loc_long': '-118.50706815',
#   'location': '13600 BAYLISS ROAD',
#   'make': 'TSMR',
#   'marked_time': '0000',
#   'meter_id': None,
#   'plate_expiry_date': '0',
#   'rp_state_plate': 'CA',
#   'ticket_number': '4543639166',
#   'violation_code': '5204A-',
#   'violation_description': 'DISPLAY OF TABS'},
#  {'agency': '51',
#   'agency_desc': '51 - DOT - WESTERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'BL',
#   'color_desc': 'BLUE',
#   'fine_amount': '68',
#   'issue_date': '2002-07-17T00:00:00.000',
#   'issue_time': '347',
#   'loc_lat': '33.99957383',
#   'loc_long': '-118.46239314',
#   'location': '900 LAKE ST',
#   'make': 'DODG',
#   'marked_time': '0000',
#   'meter_id': None,
#   'plate_expiry_date': '202201',
#   'rp_state_plate': 'AL',
#   'ticket_number': '4544552913',
#   'violation_code': '80.58L',
#   'violation_description': 'PREFERENTIAL PARKING'},
#  {'agency': '51',
#   'agency_desc': '51 - DOT - WESTERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'WT',
#   'color_desc': 'WHITE',
#   'fine_amount': '68',
#   'issue_date': '2002-07-17T00:00:00.000',
#   'issue_time': '348',
#   'loc_lat': '33.99974222',
#   'loc_long': '-118.46213785',
#   'location': '900 LAKE ST',
#   'make': 'FORD',
#   'marked_time': '0000',
#   'meter_id': None,
#   'plate_expiry_date': '0',
#   'rp_state_plate': 'AZ',
#   'ticket_number': '4544552924',
#   'violation_code': '80.58L',
#   'violation_description': 'PREFERENTIAL PARKING'},
#  {'agency': '51',
#   'agency_desc': '51 - DOT - WESTERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'BK',
#   'color_desc': 'BLACK',
#   'fine_amount': '73',
#   'issue_date': '2002-07-18T00:00:00.000',
#   'issue_time': '1430',
#   'loc_lat': '34.0015774',
#   'loc_long': '-118.4589347',
#   'location': '1042 ELKGROVE AVE',
#   'make': 'TOYT',
#   'marked_time': '0000',
#   'meter_id': None,
#   'plate_expiry_date': '202211',
#   'rp_state_plate': 'CA',
#   'ticket_number': '4544682881',
#   'violation_code': '80.69BS',
#   'violation_description': 'NO PARK/STREET CLEAN'},
#  {'agency': '51',
#   'agency_desc': '51 - DOT - WESTERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'OT',
#   'color_desc': 'OTHER',
#   'fine_amount': '73',
#   'issue_date': '2002-07-18T00:00:00.000',
#   'issue_time': '1431',
#   'loc_lat': '34.0016962',
#   'loc_long': '-118.4589318',
#   'location': '1038 ELKGROVE AVE',
#   'make': 'LEXS',
#   'marked_time': '0000',
#   'meter_id': None,
#   'plate_expiry_date': '202203',
#   'rp_state_plate': 'CA',
#   'ticket_number': '4544682892',
#   'violation_code': '80.69BS',
#   'violation_description': 'NO PARK/STREET CLEAN'},
#  {'agency': '55',
#   'agency_desc': '55 - DOT - SOUTHERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'SL',
#   'color_desc': 'SILVER',
#   'fine_amount': '73',
#   'issue_date': '2002-07-22T00:00:00.000',
#   'issue_time': '1646',
#   'loc_lat': '34.0263142',
#   'loc_long': '-118.3418001',
#   'location': '2911 WEST BLVD',
#   'make': 'TOYT',
#   'marked_time': '0000',
#   'meter_id': None,
#   'plate_expiry_date': '202205',
#   'rp_state_plate': 'CA',
#   'ticket_number': '4544778162',
#   'violation_code': '80.69B',
#   'violation_description': 'NO PARKING'},
#  {'agency': '55',
#   'agency_desc': '55 - DOT - SOUTHERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'SL',
#   'color_desc': 'SILVER',
#   'fine_amount': '73',
#   'issue_date': '2002-07-22T00:00:00.000',
#   'issue_time': '1648',
#   'loc_lat': '34.0263583',
#   'loc_long': '-118.3418305',
#   'location': '3000 WEST BLVD',
#   'make': 'BMW',
#   'marked_time': '0000',
#   'meter_id': None,
#   'plate_expiry_date': '202106',
#   'rp_state_plate': 'CA',
#   'ticket_number': '4544778173',
#   'violation_code': '80.69B',
#   'violation_description': 'NO PARKING'},
#  {'agency': '55',
#   'agency_desc': '55 - DOT - SOUTHERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'SL',
#   'color_desc': 'SILVER',
#   'fine_amount': '25',
#   'issue_date': '2002-07-22T00:00:00.000',
#   'issue_time': '1649',
#   'loc_lat': '34.0259881',
#   'loc_long': '-118.3418167',
#   'location': '3000 WEST BLVD',
#   'make': 'BMW',
#   'marked_time': '0000',
#   'meter_id': None,
#   'plate_expiry_date': '202106',
#   'rp_state_plate': 'CA',
#   'ticket_number': '4544778184',
#   'violation_code': '5204A-',
#   'violation_description': 'DISPLAY OF TABS'},
#  {'agency': '55',
#   'agency_desc': '55 - DOT - SOUTHERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'RD',
#   'color_desc': 'RED',
#   'fine_amount': '25',
#   'issue_date': '2002-07-23T00:00:00.000',
#   'issue_time': '1002',
#   'loc_lat': '34.0170326',
#   'loc_long': '-118.3470559',
#   'location': '4530 COLISEUM ST S',
#   'make': 'FORD',
#   'marked_time': '0000',
#   'meter_id': None,
#   'plate_expiry_date': '201908',
#   'rp_state_plate': 'CA',
#   'ticket_number': '4544478433',
#   'violation_code': '5204A-',
#   'violation_description': 'DISPLAY OF TABS'},
#  {'agency': '54',
#   'agency_desc': '54 - DOT - HOLLYWOOD',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'WT',
#   'color_desc': 'WHITE',
#   'fine_amount': '68',
#   'issue_date': '2002-07-30T00:00:00.000',
#   'issue_time': '200',
#   'loc_lat': '34.068055',
#   'loc_long': '-118.3115625',
#   'location': '324 ST ANDREWS PL S',
#   'make': 'ISU',
#   'marked_time': '0000',
#   'meter_id': None,
#   'plate_expiry_date': '202209',
#   'rp_state_plate': 'CA',
#   'ticket_number': '4543714125',
#   'violation_code': '22500E',
#   'violation_description': 'BLOCKING DRIVEWAY'},
#  {'agency': '2',
#   'agency_desc': 'LAX CURRENT',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'RE',
#   'color_desc': None,
#   'fine_amount': None,
#   'issue_date': '2002-07-31T00:00:00.000',
#   'issue_time': '2323',
#   'loc_lat': '33.9442025',
#   'loc_long': '-118.4078454',
#   'location': '380 WORLD WAY U/L',
#   'make': 'MAZD',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': '202009',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1127503064',
#   'violation_code': None,
#   'violation_description': None},
#  {'agency': '53',
#   'agency_desc': '53 - DOT - VALLEY',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'RD',
#   'color_desc': 'RED',
#   'fine_amount': '93',
#   'issue_date': '2002-08-08T00:00:00.000',
#   'issue_time': '319',
#   'loc_lat': '34.2157744',
#   'loc_long': '-118.5348777',
#   'location': '18400 STRATHERN ST',
#   'make': 'HOND',
#   'marked_time': '0000',
#   'meter_id': None,
#   'plate_expiry_date': '202207',
#   'rp_state_plate': 'CA',
#   'ticket_number': '4545314034',
#   'violation_code': '80.56E4+',
#   'violation_description': 'RED ZONE'},
#  {'agency': '54',
#   'agency_desc': '54 - DOT - HOLLYWOOD',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'GN',
#   'color_desc': 'GREEN',
#   'fine_amount': '63',
#   'issue_date': '2002-08-13T00:00:00.000',
#   'issue_time': '1013',
#   'loc_lat': '34.0894469',
#   'loc_long': '-118.309029',
#   'location': '5401 SIERRA VISTA AV',
#   'make': 'HOND',
#   'marked_time': '0000',
#   'meter_id': 'SW495',
#   'plate_expiry_date': '202208',
#   'rp_state_plate': 'NV',
#   'ticket_number': '4546061063',
#   'violation_code': '88.13B+',
#   'violation_description': 'METER EXP.'},
#  {'agency': '54',
#   'agency_desc': '54 - DOT - HOLLYWOOD',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'GY',
#   'color_desc': 'GREY',
#   'fine_amount': '63',
#   'issue_date': '2002-08-15T00:00:00.000',
#   'issue_time': '1228',
#   'loc_lat': '34.0689186',
#   'loc_long': '-118.3082755',
#   'location': '4301 3RD ST W',
#   'make': 'TOYT',
#   'marked_time': '0000',
#   'meter_id': 'WW78',
#   'plate_expiry_date': '202209',
#   'rp_state_plate': 'CA',
#   'ticket_number': '4545490305',
#   'violation_code': '88.13B+',
#   'violation_description': 'METER EXP.'},
#  {'agency': '53',
#   'agency_desc': '53 - DOT - VALLEY',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'RD',
#   'color_desc': 'RED',
#   'fine_amount': '73',
#   'issue_date': '2002-08-19T00:00:00.000',
#   'issue_time': '2232',
#   'loc_lat': '34.2036222',
#   'loc_long': '-118.5391237',
#   'location': '18601 GAULT ST',
#   'make': 'JEEP',
#   'marked_time': '0000',
#   'meter_id': None,
#   'plate_expiry_date': '202209',
#   'rp_state_plate': 'CA',
#   'ticket_number': '4545435403',
#   'violation_code': '80.69B',
#   'violation_description': 'NO PARKING'},
#  {'agency': '54',
#   'agency_desc': '54 - DOT - HOLLYWOOD',
#   'body_style': 'TK',
#   'body_style_desc': 'TRUCK',
#   'color': 'WT',
#   'color_desc': 'WHITE',
#   'fine_amount': '73',
#   'issue_date': '2002-09-17T00:00:00.000',
#   'issue_time': '1042',
#   'loc_lat': '34.0987155',
#   'loc_long': '-118.3197045',
#   'location': '1508 GORDON ST',
#   'make': 'DODG',
#   'marked_time': '0000',
#   'meter_id': None,
#   'plate_expiry_date': '202210',
#   'rp_state_plate': 'CA',
#   'ticket_number': '4547546625',
#   'violation_code': '80.69BS',
#   'violation_description': 'NO PARK/STREET CLEAN'},
#  {'agency': '53',
#   'agency_desc': '53 - DOT - VALLEY',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': None,
#   'color_desc': None,
#   'fine_amount': '68',
#   'issue_date': '2002-10-09T00:00:00.000',
#   'issue_time': '1058',
#   'loc_lat': '34.2085555',
#   'loc_long': '-118.5328579',
#   'location': '18325 SATICOY ST',
#   'make': 'HOND',
#   'marked_time': '0000',
#   'meter_id': None,
#   'plate_expiry_date': '202202',
#   'rp_state_plate': 'CA',
#   'ticket_number': '4549643604',
#   'violation_code': '80.73.2',
#   'violation_description': 'EXCEED 72HRS-ST'},
#  {'agency': '1',
#   'agency_desc': 'WESTERN',
#   'body_style': 'SU',
#   'body_style_desc': None,
#   'color': 'BK',
#   'color_desc': 'BLACK',
#   'fine_amount': '93',
#   'issue_date': '2003-02-24T00:00:00.000',
#   'issue_time': '1230',
#   'loc_lat': '34.0357180',
#   'loc_long': '-118.2596150',
#   'location': '1301 S LOS ANGELES',
#   'make': 'BMW',
#   'marked_time': '0000',
#   'meter_id': None,
#   'plate_expiry_date': '202305',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1131979741',
#   'violation_code': None,
#   'violation_description': None},
#  {'agency': '4',
#   'agency_desc': 'HOLLYWOOD',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'WH',
#   'color_desc': None,
#   'fine_amount': '93',
#   'issue_date': '2003-04-15T00:00:00.000',
#   'issue_time': '1642',
#   'loc_lat': '34.1181176',
#   'loc_long': '-118.2937324',
#   'location': '2900 N VERMONT AVE',
#   'make': 'BMW',
#   'marked_time': '0000',
#   'meter_id': None,
#   'plate_expiry_date': '0',
#   'rp_state_plate': 'FL',
#   'ticket_number': '1113781911',
#   'violation_code': None,
#   'violation_description': None},
#  {'agency': '1',
#   'agency_desc': 'WESTERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'GY',
#   'color_desc': 'GREY',
#   'fine_amount': '93',
#   'issue_date': '2003-04-24T00:00:00.000',
#   'issue_time': '1135',
#   'loc_lat': '34.1590728',
#   'loc_long': '-118.5566366',
#   'location': 'PIERCE/PALA',
#   'make': 'HOND',
#   'marked_time': '0000',
#   'meter_id': None,
#   'plate_expiry_date': '202304',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1115928483',
#   'violation_code': None,
#   'violation_description': None},
#  {'agency': '36',
#   'agency_desc': 'LAPD SECURITY SERVICES',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'WH',
#   'color_desc': None,
#   'fine_amount': '68',
#   'issue_date': '2003-09-26T00:00:00.000',
#   'issue_time': '1020',
#   'loc_lat': '34.0500342',
#   'loc_long': '-118.2342969',
#   'location': '520 EAST TEMPLE ST',
#   'make': 'TOYO',
#   'marked_time': '0000',
#   'meter_id': None,
#   'plate_expiry_date': '0',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1127759791',
#   'violation_code': None,
#   'violation_description': None},
#  {'agency': '41',
#   'agency_desc': 'STREET USE INSPECTORS',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'GY',
#   'color_desc': 'GREY',
#   'fine_amount': '93',
#   'issue_date': '2003-12-29T00:00:00.000',
#   'issue_time': '1235',
#   'loc_lat': '34.0384400',
#   'loc_long': '-118.2610200',
#   'location': '160 W 12TH ST',
#   'make': 'BENZ',
#   'marked_time': '0000',
#   'meter_id': None,
#   'plate_expiry_date': '202410',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1123480190',
#   'violation_code': None,
#   'violation_description': None},
#  {'agency': '1',
#   'agency_desc': 'WESTERN',
#   'body_style': 'SU',
#   'body_style_desc': None,
#   'color': 'BR',
#   'color_desc': None,
#   'fine_amount': '363',
#   'issue_date': '2004-02-11T00:00:00.000',
#   'issue_time': '1533',
#   'loc_lat': '34.0864699',
#   'loc_long': '-118.3532527',
#   'location': 'GARDNER ST S/O MELRO',
#   'make': 'CADI',
#   'marked_time': '0000',
#   'meter_id': None,
#   'plate_expiry_date': '202406',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1129988823',
#   'violation_code': None,
#   'violation_description': None},
#  {'agency': '1',
#   'agency_desc': 'WESTERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'GY',
#   'color_desc': 'GREY',
#   'fine_amount': '68',
#   'issue_date': '2004-02-11T00:00:00.000',
#   'issue_time': '1546',
#   'loc_lat': '34.0823647',
#   'loc_long': '-118.3535279',
#   'location': '617 N GARDNER ST',
#   'make': 'HOND',
#   'marked_time': '0000',
#   'meter_id': None,
#   'plate_expiry_date': '202407',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1129988834',
#   'violation_code': None,
#   'violation_description': None},
#  {'agency': '4',
#   'agency_desc': 'HOLLYWOOD',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'WH',
#   'color_desc': None,
#   'fine_amount': '0',
#   'issue_date': '2004-03-03T00:00:00.000',
#   'issue_time': '1133',
#   'loc_lat': '34.0953775',
#   'loc_long': '-118.2917693',
#   'location': 'N VERMONT RD',
#   'make': 'DODG',
#   'marked_time': '0000',
#   'meter_id': None,
#   'plate_expiry_date': '0',
#   'rp_state_plate': 'AZ',
#   'ticket_number': '1113490420',
#   'violation_code': None,
#   'violation_description': None},
#  {'agency': '56',
#   'agency_desc': '56 - DOT - CENTRAL',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'BK',
#   'color_desc': 'BLACK',
#   'fine_amount': '70',
#   'issue_date': '2008-02-04T00:00:00.000',
#   'issue_time': '1845',
#   'loc_lat': '34.05718884',
#   'loc_long': '-118.27420282',
#   'location': '1920 WILSHIRE BLVD',
#   'make': 'FORD',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': None,
#   'rp_state_plate': 'CA',
#   'ticket_number': '2012908925',
#   'violation_code': None,
#   'violation_description': None},
#  {'agency': '51',
#   'agency_desc': '51 - DOT - WESTERN',
#   'body_style': 'TR',
#   'body_style_desc': 'TRAILER',
#   'color': 'GY',
#   'color_desc': 'GREY',
#   'fine_amount': None,
#   'issue_date': '2009-07-19T00:00:00.000',
#   'issue_time': '1909',
#   'loc_lat': '34.04709527',
#   'loc_long': '-118.52418671',
#   'location': '1000 MONUMENT ST',
#   'make': 'TOYO',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': '202101',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1126931606',
#   'violation_code': '8058L',
#   'violation_description': None},
#  {'agency': '3',
#   'agency_desc': 'VALLEY',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'GY',
#   'color_desc': 'GREY',
#   'fine_amount': None,
#   'issue_date': '2009-09-09T00:00:00.000',
#   'issue_time': '1325',
#   'loc_lat': '34.0751824',
#   'loc_long': '-118.2797263',
#   'location': 'B 93',
#   'make': 'CADI',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': '201912',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1127613664',
#   'violation_code': '8709D',
#   'violation_description': None},
#  {'agency': '1',
#   'agency_desc': 'WESTERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'BK',
#   'color_desc': 'BLACK',
#   'fine_amount': '25',
#   'issue_date': '2010-01-09T00:00:00.000',
#   'issue_time': '750',
#   'loc_lat': '34.218798',
#   'loc_long': '-118.452807',
#   'location': '8113 CEDROS',
#   'make': 'NISS',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': None,
#   'rp_state_plate': 'CA',
#   'ticket_number': '1120588372',
#   'violation_code': '5204A',
#   'violation_description': 'EXPIRED TAGS'},
#  {'agency': '58',
#   'agency_desc': '58 - SPECIAL EVENTS',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'GY',
#   'color_desc': 'GREY',
#   'fine_amount': None,
#   'issue_date': '2010-01-26T00:00:00.000',
#   'issue_time': '1445',
#   'loc_lat': '34.0436500',
#   'loc_long': '-118.2632400',
#   'location': '1024 S FLOWER ST',
#   'make': 'HOND',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': '202006',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1126738292',
#   'violation_code': '8069A',
#   'violation_description': None},
#  {'agency': '55',
#   'agency_desc': '55 - DOT - SOUTHERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'GY',
#   'color_desc': 'GREY',
#   'fine_amount': None,
#   'issue_date': '2010-02-03T00:00:00.000',
#   'issue_time': '501',
#   'loc_lat': '34.01284735',
#   'loc_long': '-118.3542228',
#   'location': '4000 S LA BREA AVE',
#   'make': 'CHEV',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': '201807',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1111002093',
#   'violation_code': '8606',
#   'violation_description': 'PK OTSD PSTD AR'},
#  {'agency': '1',
#   'agency_desc': 'WESTERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'GO',
#   'color_desc': 'GOLD',
#   'fine_amount': None,
#   'issue_date': '2010-02-05T00:00:00.000',
#   'issue_time': '1440',
#   'loc_lat': '33.9330369',
#   'loc_long': '-118.2463088',
#   'location': 'ALLEY 1600 E 112TH',
#   'make': 'TOYO',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': '202002',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1120715676',
#   'violation_code': '8061',
#   'violation_description': None},
#  {'agency': '2',
#   'agency_desc': 'LAX CURRENT',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'BK',
#   'color_desc': 'BLACK',
#   'fine_amount': None,
#   'issue_date': '2010-02-08T00:00:00.000',
#   'issue_time': '1550',
#   'loc_lat': '33.9533718',
#   'loc_long': '-118.3892247',
#   'location': '9100 JENNY AVE',
#   'make': 'KIA',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': '201802',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1122736602',
#   'violation_code': None,
#   'violation_description': None},
#  {'agency': '51',
#   'agency_desc': '51 - DOT - WESTERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'BK',
#   'color_desc': 'BLACK',
#   'fine_amount': None,
#   'issue_date': '2010-02-26T00:00:00.000',
#   'issue_time': '1811',
#   'loc_lat': '34.041304',
#   'loc_long': '-118.4322508',
#   'location': '2371 S KELTON AVE',
#   'make': 'TOYO',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': '202010',
#   'rp_state_plate': 'AZ',
#   'ticket_number': '1126924993',
#   'violation_code': '8058L',
#   'violation_description': None},
#  {'agency': '53',
#   'agency_desc': '53 - DOT - VALLEY',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'GY',
#   'color_desc': 'GREY',
#   'fine_amount': None,
#   'issue_date': '2010-04-10T00:00:00.000',
#   'issue_time': '1807',
#   'loc_lat': '34.14230531',
#   'loc_long': '-118.40294896',
#   'location': '3900 RADFORD AVE',
#   'make': 'VOLK',
#   'marked_time': None,
#   'meter_id': '57',
#   'plate_expiry_date': '201712',
#   'rp_state_plate': 'TX',
#   'ticket_number': '1126294783',
#   'violation_code': '8058L',
#   'violation_description': 'PREF PARKING'},
#  {'agency': '54',
#   'agency_desc': '54 - DOT - HOLLYWOOD',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'WH',
#   'color_desc': None,
#   'fine_amount': None,
#   'issue_date': '2010-05-03T00:00:00.000',
#   'issue_time': '1240',
#   'loc_lat': '34.0633411',
#   'loc_long': '-118.306619',
#   'location': '600 S SERRANO AV',
#   'make': 'KIA',
#   'marked_time': None,
#   'meter_id': 'WW1731',
#   'plate_expiry_date': '201411',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1107495432',
#   'violation_code': '8813B',
#   'violation_description': 'METER EXPIRED'},
#  {'agency': '1',
#   'agency_desc': 'WESTERN',
#   'body_style': 'TR',
#   'body_style_desc': 'TRAILER',
#   'color': 'BL',
#   'color_desc': 'BLUE',
#   'fine_amount': '50',
#   'issue_date': '2010-05-22T00:00:00.000',
#   'issue_time': '1620',
#   'loc_lat': '34.0455364',
#   'loc_long': '-118.2448840',
#   'location': 'WALL/WINSTON',
#   'make': 'JEEP',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': '201803',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1120601506',
#   'violation_code': '4000A1',
#   'violation_description': 'NO EVIDENCE OF REG'},
#  {'agency': '1',
#   'agency_desc': 'WESTERN',
#   'body_style': 'SU',
#   'body_style_desc': None,
#   'color': 'GO',
#   'color_desc': 'GOLD',
#   'fine_amount': None,
#   'issue_date': '2010-05-28T00:00:00.000',
#   'issue_time': '515',
#   'loc_lat': '33.8678362',
#   'loc_long': '-117.8623203',
#   'location': '2800 E LANCASTER AV',
#   'make': 'INFI',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': None,
#   'rp_state_plate': 'CA',
#   'ticket_number': '1105616433',
#   'violation_code': '8058L',
#   'violation_description': 'PREF PARKING'},
#  {'agency': '54',
#   'agency_desc': '54 - DOT - HOLLYWOOD',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'RE',
#   'color_desc': None,
#   'fine_amount': '93',
#   'issue_date': '2010-06-09T00:00:00.000',
#   'issue_time': '231',
#   'loc_lat': '34.0548461',
#   'loc_long': '-118.2870598',
#   'location': '2780 SAN MARINO',
#   'make': 'HOND',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': None,
#   'rp_state_plate': 'CA',
#   'ticket_number': '1126250053',
#   'violation_code': '8056E4',
#   'violation_description': 'RED ZONE'},
#  {'agency': '55',
#   'agency_desc': '55 - DOT - SOUTHERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'GY',
#   'color_desc': 'GREY',
#   'fine_amount': None,
#   'issue_date': '2010-06-09T00:00:00.000',
#   'issue_time': '510',
#   'loc_lat': '33.731135',
#   'loc_long': '-118.287893',
#   'location': '1432 PACIFIC AVE',
#   'make': 'ACUR',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': '201602',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1112627854',
#   'violation_code': '8069BS',
#   'violation_description': 'NO PARK/STREET CLEAN'},
#  {'agency': '4',
#   'agency_desc': 'HOLLYWOOD',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'SI',
#   'color_desc': None,
#   'fine_amount': None,
#   'issue_date': '2010-06-09T00:00:00.000',
#   'issue_time': '1715',
#   'loc_lat': '34.123247',
#   'loc_long': '-118.302221',
#   'location': '2800 W OBSERVATORY',
#   'make': 'CHEV',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': None,
#   'rp_state_plate': 'AZ',
#   'ticket_number': '1111565582',
#   'violation_code': '8056E4',
#   'violation_description': 'RED ZONE'},
#  {'agency': '55',
#   'agency_desc': '55 - DOT - SOUTHERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'WH',
#   'color_desc': None,
#   'fine_amount': '25',
#   'issue_date': '2010-06-25T00:00:00.000',
#   'issue_time': '343',
#   'loc_lat': '33.994167',
#   'loc_long': '-118.269976',
#   'location': '300 E 53RD ST',
#   'make': 'CHEV',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': '201812',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1114885273',
#   'violation_code': '098',
#   'violation_description': '5200'},
#  {'agency': '2',
#   'agency_desc': 'LAX CURRENT',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'GR',
#   'color_desc': None,
#   'fine_amount': '25',
#   'issue_date': '2010-07-17T00:00:00.000',
#   'issue_time': '1840',
#   'loc_lat': '33.9442025',
#   'loc_long': '-118.4078454',
#   'location': '301 WORLD WAY',
#   'make': 'SUBA',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': '201705',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1112263655',
#   'violation_code': '5204A',
#   'violation_description': 'EXPIRED TAGS'},
#  {'agency': '54',
#   'agency_desc': '54 - DOT - HOLLYWOOD',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'GY',
#   'color_desc': 'GREY',
#   'fine_amount': '60',
#   'issue_date': '2010-09-08T00:00:00.000',
#   'issue_time': '127',
#   'loc_lat': '34.087663',
#   'loc_long': '-118.284815',
#   'location': '4200 W BURNS AVE',
#   'make': 'JEEP',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': '201604',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1114299340',
#   'violation_code': '024',
#   'violation_description': '22514'},
#  {'agency': '1',
#   'agency_desc': 'WESTERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'BK',
#   'color_desc': 'BLACK',
#   'fine_amount': '50',
#   'issue_date': '2010-09-10T00:00:00.000',
#   'issue_time': '1420',
#   'loc_lat': '34.0358748',
#   'loc_long': '-118.2460182',
#   'location': '8TH/GLADYS',
#   'make': 'MAZD',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': '201908',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1121424474',
#   'violation_code': '4000A1',
#   'violation_description': 'NO EVIDENCE OF REG'},
#  {'agency': '4',
#   'agency_desc': 'HOLLYWOOD',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'WH',
#   'color_desc': None,
#   'fine_amount': '85',
#   'issue_date': '2010-09-24T00:00:00.000',
#   'issue_time': '1022',
#   'loc_lat': '34.1217554',
#   'loc_long': '-118.3018643',
#   'location': 'WEST OBSERVATORY RD',
#   'make': 'NISS',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': None,
#   'rp_state_plate': 'AZ',
#   'ticket_number': '1109180866',
#   'violation_code': '8056E4',
#   'violation_description': 'RED ZONE'},
#  {'agency': '1',
#   'agency_desc': 'WESTERN',
#   'body_style': 'VN',
#   'body_style_desc': 'VAN',
#   'color': None,
#   'color_desc': None,
#   'fine_amount': '85',
#   'issue_date': '2010-09-29T00:00:00.000',
#   'issue_time': '1630',
#   'loc_lat': '33.9832546',
#   'loc_long': '-118.3046038',
#   'location': '62ND ST/DENKER',
#   'make': 'GMC',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': '201910',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1110866654',
#   'violation_code': '8069A',
#   'violation_description': 'NO STOPPING/STANDING'},
#  {'agency': '4',
#   'agency_desc': 'HOLLYWOOD',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'WH',
#   'color_desc': None,
#   'fine_amount': '85',
#   'issue_date': '2010-10-04T00:00:00.000',
#   'issue_time': '1930',
#   'loc_lat': '34.123247',
#   'loc_long': '-118.302221',
#   'location': '2800 W OBSERVATORY',
#   'make': 'FORD',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': '201502',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1111498850',
#   'violation_code': '8056E4',
#   'violation_description': 'RED ZONE'},
#  {'agency': '2',
#   'agency_desc': 'LAX CURRENT',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'GY',
#   'color_desc': 'GREY',
#   'fine_amount': '85',
#   'issue_date': '2010-10-05T00:00:00.000',
#   'issue_time': '1055',
#   'loc_lat': '33.9442025',
#   'loc_long': '-118.4078454',
#   'location': '380 WORLD WAY U/L',
#   'make': 'JEEP',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': '201603',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1112044080',
#   'violation_code': '8936',
#   'violation_description': 'RED CURB'},
#  {'agency': '4',
#   'agency_desc': 'HOLLYWOOD',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'WH',
#   'color_desc': None,
#   'fine_amount': '60',
#   'issue_date': '2010-10-07T00:00:00.000',
#   'issue_time': '1231',
#   'loc_lat': '34.129950',
#   'loc_long': '-118.321452',
#   'location': '3300 N LEDGEWOOD DR',
#   'make': 'CHEV',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': '201809',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1117046453',
#   'violation_code': '8058L',
#   'violation_description': 'PREF PARKING'},
#  {'agency': '1',
#   'agency_desc': 'WESTERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'WH',
#   'color_desc': None,
#   'fine_amount': '85',
#   'issue_date': '2010-10-10T00:00:00.000',
#   'issue_time': '50',
#   'loc_lat': '33.9468353',
#   'loc_long': '-118.3090205',
#   'location': 'WESTERN AVE/98TH ST',
#   'make': 'TOYO',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': '200821',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1115500514',
#   'violation_code': '8056E4',
#   'violation_description': None},
#  {'agency': '2',
#   'agency_desc': 'LAX CURRENT',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'GY',
#   'color_desc': 'GREY',
#   'fine_amount': '50',
#   'issue_date': '2010-10-10T00:00:00.000',
#   'issue_time': '905',
#   'loc_lat': '33.9430863',
#   'loc_long': '-118.3995274',
#   'location': '700 WORLD WAY U/L',
#   'make': 'TOYO',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': '201811',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1127238862',
#   'violation_code': '8939',
#   'violation_description': 'WHITE CURB'},
#  {'agency': '1',
#   'agency_desc': 'WESTERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'GY',
#   'color_desc': 'GREY',
#   'fine_amount': '85',
#   'issue_date': '2010-10-18T00:00:00.000',
#   'issue_time': '2220',
#   'loc_lat': '34.1304707',
#   'loc_long': '-118.3577001',
#   'location': '7701 MULHOLLAND DR',
#   'make': 'TOYO',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': '201902',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1115965384',
#   'violation_code': '8069AP',
#   'violation_description': 'NO STOP/STAND PM'},
#  {'agency': '1',
#   'agency_desc': 'WESTERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'BU',
#   'color_desc': None,
#   'fine_amount': '60',
#   'issue_date': '2010-10-20T00:00:00.000',
#   'issue_time': '1215',
#   'loc_lat': '34.0309640',
#   'loc_long': '-118.2448113',
#   'location': 'REAR ALLEY 1660 E 11',
#   'make': 'TOYO',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': '201905',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1121651812',
#   'violation_code': '8061',
#   'violation_description': None},
#  {'agency': '2',
#   'agency_desc': 'LAX CURRENT',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'WH',
#   'color_desc': None,
#   'fine_amount': '50',
#   'issue_date': '2010-10-20T00:00:00.000',
#   'issue_time': '1935',
#   'loc_lat': '33.94636260000001',
#   'loc_long': '-118.4010845',
#   'location': '100 WORLD WAY L/L',
#   'make': 'MERZ',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': '201706',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1112305154',
#   'violation_code': '8939',
#   'violation_description': 'WHITE CURB'},
#  {'agency': '57',
#   'agency_desc': '57 - HABITUAL VIOLATORS',
#   'body_style': 'TR',
#   'body_style_desc': 'TRAILER',
#   'color': 'GY',
#   'color_desc': 'GREY',
#   'fine_amount': '55',
#   'issue_date': '2010-10-22T00:00:00.000',
#   'issue_time': '1104',
#   'loc_lat': '33.9935311',
#   'loc_long': '-118.4067971',
#   'location': '501 S SLAUSON AVE',
#   'make': 'FORD',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': '201909',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1126070035',
#   'violation_code': '018',
#   'violation_description': '22502A'},
#  {'agency': '51',
#   'agency_desc': '51 - DOT - WESTERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'GY',
#   'color_desc': 'GREY',
#   'fine_amount': '65',
#   'issue_date': '2010-10-24T00:00:00.000',
#   'issue_time': '1239',
#   'loc_lat': '34.0394129',
#   'loc_long': '-118.4537632',
#   'location': '1800 S STONER AVE',
#   'make': 'CHEV',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': '202003',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1116432796',
#   'violation_code': '8069BS',
#   'violation_description': None},
#  {'agency': '55',
#   'agency_desc': '55 - DOT - SOUTHERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'BK',
#   'color_desc': 'BLACK',
#   'fine_amount': '65',
#   'issue_date': '2010-10-25T00:00:00.000',
#   'issue_time': '748',
#   'loc_lat': '33.938225',
#   'loc_long': '-118.262817',
#   'location': '737 E 108TH ST',
#   'make': 'AUDI',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': '201605',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1126567094',
#   'violation_code': '8069BS',
#   'violation_description': 'NO PARK/STREET CLEAN'},
#  {'agency': '54',
#   'agency_desc': '54 - DOT - HOLLYWOOD',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'GY',
#   'color_desc': 'GREY',
#   'fine_amount': '50',
#   'issue_date': '2010-10-27T00:00:00.000',
#   'issue_time': '651',
#   'loc_lat': '34.07077',
#   'loc_long': '-118.27938',
#   'location': '147 N OCCIDENTAL',
#   'make': 'JEEP',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': '201807',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1116923824',
#   'violation_code': '8056E1',
#   'violation_description': 'WHITE ZONE'},
#  {'agency': '1',
#   'agency_desc': 'WESTERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'RE',
#   'color_desc': None,
#   'fine_amount': '25',
#   'issue_date': '2010-10-30T00:00:00.000',
#   'issue_time': '325',
#   'loc_lat': '34.01813584',
#   'loc_long': '-118.29442357',
#   'location': '1100 EXPOSITION BLVD',
#   'make': 'LEXU',
#   'marked_time': '0000',
#   'meter_id': None,
#   'plate_expiry_date': '201508',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1121757755',
#   'violation_code': '5200A',
#   'violation_description': None},
#  {'agency': '1',
#   'agency_desc': 'WESTERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'WH',
#   'color_desc': None,
#   'fine_amount': '60',
#   'issue_date': '2010-11-04T00:00:00.000',
#   'issue_time': '1746',
#   'loc_lat': '33.78713514',
#   'loc_long': '-118.29597916',
#   'location': '25820 VERMONT AVE',
#   'make': 'CHEV',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': '201902',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1122216152',
#   'violation_code': '8603',
#   'violation_description': 'PK IN PROH AREA'},
#  {'agency': '54',
#   'agency_desc': '54 - DOT - HOLLYWOOD',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'GY',
#   'color_desc': 'GREY',
#   'fine_amount': '85',
#   'issue_date': '2010-11-29T00:00:00.000',
#   'issue_time': '649',
#   'loc_lat': '34.0707272',
#   'loc_long': '-118.2746265',
#   'location': '206 N CORONADO',
#   'make': 'MAZD',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': '202006',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1126845392',
#   'violation_code': '8056E4',
#   'violation_description': None},
#  {'agency': '1',
#   'agency_desc': 'WESTERN',
#   'body_style': 'TR',
#   'body_style_desc': 'TRAILER',
#   'color': 'WH',
#   'color_desc': None,
#   'fine_amount': '155',
#   'issue_date': '2010-12-03T00:00:00.000',
#   'issue_time': '1612',
#   'loc_lat': '34.1578298',
#   'loc_long': '-118.494924',
#   'location': '16608 VENTURA BL',
#   'make': 'TOYO',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': '201812',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1116603751',
#   'violation_code': '8070',
#   'violation_description': 'PARK IN GRID LOCK ZN'},
#  {'agency': '1',
#   'agency_desc': 'WESTERN',
#   'body_style': 'SU',
#   'body_style_desc': None,
#   'color': 'YE',
#   'color_desc': 'YELLOW',
#   'fine_amount': '68',
#   'issue_date': '2010-12-08T00:00:00.000',
#   'issue_time': '50',
#   'loc_lat': '34.099711',
#   'loc_long': '-118.331242',
#   'location': '6520 HOLLYWOOD',
#   'make': 'LAMB',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': '202003',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1113166574',
#   'violation_code': '8069B',
#   'violation_description': None},
#  {'agency': '55',
#   'agency_desc': '55 - DOT - SOUTHERN',
#   'body_style': 'TR',
#   'body_style_desc': 'TRAILER',
#   'color': 'WH',
#   'color_desc': None,
#   'fine_amount': '25',
#   'issue_date': '2011-01-12T00:00:00.000',
#   'issue_time': '1118',
#   'loc_lat': '33.9646221',
#   'loc_long': '-118.2831378',
#   'location': '509 W 82ND ST',
#   'make': 'HOND',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': '201806',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1126565090',
#   'violation_code': '5204A',
#   'violation_description': 'EXPIRED TAGS'},
#  {'agency': '51',
#   'agency_desc': '51 - DOT - WESTERN',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'BL',
#   'color_desc': 'BLUE',
#   'fine_amount': '68',
#   'issue_date': '2011-02-04T00:00:00.000',
#   'issue_time': '808',
#   'loc_lat': '33.987570',
#   'loc_long': '-118.457407',
#   'location': '600 BLK MARR ST',
#   'make': 'TOYO',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': '201409',
#   'rp_state_plate': 'AZ',
#   'ticket_number': '1107241063',
#   'violation_code': '8069BS',
#   'violation_description': 'NO PARK/STREET CLEAN'},
#  {'agency': '54',
#   'agency_desc': '54 - DOT - HOLLYWOOD',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'BK',
#   'color_desc': 'BLACK',
#   'fine_amount': '88',
#   'issue_date': '2011-02-10T00:00:00.000',
#   'issue_time': '142',
#   'loc_lat': '34.0891637',
#   'loc_long': '-118.2681674',
#   'location': '2900 W EFFIE ST',
#   'make': 'HOND',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': '201710',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1125735354',
#   'violation_code': None,
#   'violation_description': None},
#  {'agency': '54',
#   'agency_desc': '54 - DOT - HOLLYWOOD',
#   'body_style': 'PA',
#   'body_style_desc': 'PASSENGER CAR',
#   'color': 'BK',
#   'color_desc': 'BLACK',
#   'fine_amount': '68',
#   'issue_date': '2011-02-12T00:00:00.000',
#   'issue_time': '1100',
#   'loc_lat': '34.0980995',
#   'loc_long': '-118.3114655',
#   'location': '1500 N ST ANDREWS PL',
#   'make': 'NISS',
#   'marked_time': None,
#   'meter_id': None,
#   'plate_expiry_date': '201405',
#   'rp_state_plate': 'CA',
#   'ticket_number': '1108239801',
#   'violation_code': '8069BS',
#   'violation_description': 'NO PARK/STREET CLEAN'}]

# %%
# merging ticket data 
limit = 100

# Add more rows, apply merge function
fetch_additional_records(base_url, limit, existing, schema, headers)
# Out:
# Added 100 new records to the existing data.

# %%
print(existing[0])
# Out:
# {'agency': '2', 'agency_desc': 'LAX CURRENT', 'body_style': 'PA', 'body_style_desc': 'PASSENGER CAR', 'color': 'WH', 'color_desc': None, 'fine_amount': None, 'issue_date': '1950-07-15T00:00:00.000', 'issue_time': '1550', 'loc_lat': '33.9430863', 'loc_long': '-118.3995274', 'location': '701 WORLD WAY', 'make': 'LAND', 'marked_time': None, 'meter_id': None, 'plate_expiry_date': '201910', 'rp_state_plate': 'CA', 'ticket_number': '1127488375', 'violation_code': None, 'violation_description': None}

# %%
df = pd.DataFrame(existing)
display(df)
# Out:
#     agency         agency_desc body_style body_style_desc color color_desc  \
# 0        2         LAX CURRENT         PA   PASSENGER CAR    WH       None
# 1        1             WESTERN         SU            None    BK      BLACK
# 2        1             WESTERN         PA   PASSENGER CAR    BK      BLACK
# 3        1             WESTERN         PA   PASSENGER CAR    GY       GREY
# 4        1             WESTERN         PA   PASSENGER CAR    TA       None
# ..     ...                 ...        ...             ...   ...        ...
# 195      1             WESTERN         PA   PASSENGER CAR    YE     YELLOW
# 196      4           HOLLYWOOD         PA   PASSENGER CAR    GY       GREY
# 197      2         LAX CURRENT         TR         TRAILER    WH       None
# 198     53   53 - DOT - VALLEY         PA   PASSENGER CAR    MA       None
# 199     56  56 - DOT - CENTRAL         SU            None    BK      BLACK
#
#     fine_amount               issue_date issue_time     loc_lat      loc_long  \
# 0          None  1950-07-15T00:00:00.000       1550  33.9430863  -118.3995274
# 1          None  1962-01-30T00:00:00.000       1650  34.0337275  -118.2653638
# 2          None  1970-01-31T00:00:00.000       1840  34.0367254  -118.2682253
# 3          None  1972-01-22T00:00:00.000       1555  34.1564506  -118.4391616
# 4          None  1972-01-30T00:00:00.000       1805  34.0451361   -118.256675
# ..          ...                      ...        ...         ...           ...
# 195          73  2012-07-18T00:00:00.000       2330  34.0384125   -118.230275
# 196          63  2012-07-20T00:00:00.000       2308   34.123247   -118.302221
# 197          53  2012-07-29T00:00:00.000       2250  33.9442025  -118.4078454
# 198          68  2012-08-04T00:00:00.000       1212  34.1631709  -118.6044432
# 199          68  2012-08-10T00:00:00.000        831  34.0781811  -118.2564726
#
#                 location  make marked_time meter_id plate_expiry_date  \
# 0          701 WORLD WAY  LAND        None     None            201910
# 1     8TH ST W/O HILL ST  JEEP        None   CB3235            202005
# 2        VENICE-PEMBROKE  HOND        None     None            202003
# 3     14000 RIVERSIDE DR  TOYO        None     None            202009
# 4       8TH ST W/O OLIVE  TOYO        None     None            202004
# ..                   ...   ...         ...      ...               ...
# 195        6TH ST BRIDGE  NISS        0000     None                 0
# 196   2800 W OBSERVATORY  TOYO        None     None            201712
# 197    300 WORLD WAY L/L  None        None     None            201710
# 198      5141 DON PIO DR  LEXU        None     None            201510
# 199  1478 N FAIRBANKS PL  HYUN        None     None              None
#
#     rp_state_plate ticket_number violation_code violation_description
# 0               CA    1127488375           None                  None
# 1               CA    1121858091           None                  None
# 2               CA    1121875510           None                  None
# 3               CA    1121270581           None                  None
# 4               CA    1121858124           None                  None
# ..             ...           ...            ...                   ...
# 195             CA    1120692985          8069B                  None
# 196             CA    1117027354           8603       PK IN PROH AREA
# 197             CA    1112469864           8939            WHITE CURB
# 198             CA    1111255456         8069BS  NO PARK/STREET CLEAN
# 199             CA    1125899784         8069BS  NO PARK/STREET CLEAN
#
# [200 rows x 20 columns]

# %%
# Check for duplicate rows
duplicate_rows = df.duplicated()

print(df[duplicate_rows])
# Out:
# Empty DataFrame
# Columns: [agency, agency_desc, body_style, body_style_desc, color, color_desc, fine_amount, issue_date, issue_time, loc_lat, loc_long, location, make, marked_time, meter_id, plate_expiry_date, rp_state_plate, ticket_number, violation_code, violation_description]
# Index: []
